# %% [markdown]
# <a href="https://colab.research.google.com/github/laaria-chris/BeautifySoup-Webscrapper/blob/main/TableScrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib
import pandas as pd

# %%
url = "https://www.worldometers.info/world-population/"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"> <head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>World Population Clock: 8.2 Billion People (LIVE, 2025) - Worldometer</title><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZDP3BFSX60"></script> <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#     gtag("js", new Date());
#     gtag("config", "G-ZDP3BFSX60");
# ...

# %%
table =soup.find('table', class_='datatable')
table
# Out:
# <table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":false,"sortable":false,"pageSize":false}' data-sort-col="-1" data-sort-dir="asc"> <thead> <tr> <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false"> <span>Year<br/>(July 1)</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Population</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly %<br/>Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly<br/>Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Median<br/>Age</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sor
# ...

# %%
table.find_all('th')
# Out:
# [<th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false"> <span>Year<br/>(July 1)</span> </th>,
#  <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Population</span> </th>,
#  <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly %<br/>Change</span> </th>,
#  <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly<br/>Change</span> </th>,
#  <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Median<br/>Age</span> </th>,
#  <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Fertility<br/>Rate</span> </th>,
# ...

# %%
headers=[]
for i in table.find_all('th'):
    title=i.text
    headers.append(title)
headers
# Out:
# [' Year(July 1) ',
#  ' Population ',
#  ' Yearly %Change ',
#  ' YearlyChange ',
#  ' MedianAge ',
#  ' FertilityRate ',
#  ' Density(P/Km²) ']

# %%
df=pd.DataFrame(columns=headers)
df
# Out:
# Empty DataFrame
# Columns: [ Year(July 1) ,  Population ,  Yearly %Change ,  YearlyChange ,  MedianAge ,  FertilityRate ,  Density(P/Km²) ]
# Index: []

# %% [markdown]
# Universal code for scrapping a table

# %%
for j in table.find_all("tr")[1:]:
  row_data = j.find_all('td')
  row = [tr.text for tr in row_data]
  length = len(df)
  df.loc[length] = row
df
# Out:
#    Year(July 1)       Population  Yearly %Change  YearlyChange  MedianAge   \
# 0          2025    8,231,613,070           0.85%    69,640,498       30.9
# 1          2024    8,161,972,572           0.87%    70,237,642       30.6
# 2          2023    8,091,734,930           0.88%    70,327,738       30.4
# 3          2022    8,021,407,192           0.84%    66,958,801       30.1
# 4          2021    7,954,448,391           0.86%    67,447,099       29.8
# 5          2020    7,887,001,292           1.09%    83,301,884       29.6
# 6          2015    7,470,491,872           1.25%    89,751,945       28.3
# 7          2010    7,021,732,148           1.29%    86,952,403       27.2
# 8          2005    6,586,970,132           1.31%    83,053,428       26.1
# 9          2000    6,171,702,993           1.39%    82,564,802       25.1
# 10         1995    5,758,878,982           1.57%    86,215,174         24
# 11         1990    5,327,803,110           1.82%    91,771,929       22.9
# ...

# %%
df.to_csv(r"C:\Users\claaria\OneDrive - Deloitte (O365D)\Desktop\DS\DS Projects\Web Scrapping\table_scraped.csv")
